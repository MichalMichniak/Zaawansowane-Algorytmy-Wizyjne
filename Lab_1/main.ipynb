# %% [markdown]
# #### Zadanie 1.1

# %%
import cv2
I = cv2.imread('mandril.jpg')

# %%
cv2.imshow("mandril",I)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite("m.png",I)
# Out:
# True

# %%
print(I.shape) # dimensions /rows, columns, depth/
print(I.size) # number of bytes
print(I.dtype) # data type
# Out:
# (512, 512, 3)
# 786432
# uint8

# %% [markdown]
# ##### Zadanie 1.2

# %%
import matplotlib.pyplot as plt

I = plt.imread('mandril.jpg')

plt.figure(1) # create figure
plt.imshow(I) # add image
plt.title('Mandril') # add title
plt.axis('off') # disable display of the coordinate system
plt.show() # display

# %%
x = [ 100, 150, 200, 250]
y = [ 50, 100, 150, 200]
plt.plot(x,y,'r.',markersize=10)

# %%
from matplotlib.patches import Rectangle # add at the top of the file
fig,ax = plt.subplots(1) # instead of plt.figure(1)
rect = Rectangle((50,50),50,100,fill=False, ec='r'); # ec - edge colour
ax.add_patch(rect) # display
ax.set_xlim((0,200))
ax.set_ylim((0,200))
plt.show()

# %% [markdown]
# ##### Zadanie 1.3

# %%
IG = cv2.cvtColor(I, cv2.COLOR_BGR2GRAY)
IHSV = cv2.cvtColor(I, cv2.COLOR_BGR2HSV)

# %%
plt.figure(1) # create figure
plt.imshow(IG) # add image
plt.gray()
plt.title('Mandril') # add title
plt.axis('off') # disable display of the coordinate system
plt.show() # display

# %%
plt.figure(1) # create figure
plt.imshow(IHSV) # add image
plt.title('Mandril') # add title
plt.axis('off') # disable display of the coordinate system
plt.show() # display

# %%
for i in range(3):
    plt.figure(1) # create figure
    plt.imshow(IHSV[:,:,i]) # add image
    plt.gray()
    plt.title('Mandril') # add title
    plt.axis('off') # disable display of the coordinate system
    plt.show() # display

# %% [markdown]
# #### Zadanie 1.4

# %%
height, width =I.shape[:2] # retrieving elements 1 and 2, i.e. the corresponding height and width
scale = 1.75 # scale factor
Ix2 = cv2.resize(I,(int(scale*height),int(scale*width)))
print(Ix2.shape, I.shape)
cv2.imshow("Big Mandrill",Ix2)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (896, 896, 3) (512, 512, 3)

# %% [markdown]
# #### Zadanie 1.6

# %%
I_lena = plt.imread('lena.png')
I_lena = cv2.cvtColor(I_lena, cv2.COLOR_BGR2GRAY)

plt.figure(1) # create figure
plt.imshow(I_lena) # add image
plt.gray()
plt.title('lena') # add title
plt.axis('off') # disable display of the coordinate system
plt.show() # display

# %%
import numpy as np

plt.figure(1) # create figure
plt.imshow(I_lena + np.float64(IG)/256) # add image
plt.gray()
plt.title('suma') # add title
plt.axis('off') # disable display of the coordinate system
plt.show() # display

plt.figure(1) # create figure
plt.imshow(I_lena * np.float64(IG)/256) # add image
plt.gray()
plt.title('iloczyn') # add title
plt.axis('off') # disable display of the coordinate system
plt.show() # display

plt.figure(1) # create figure
plt.imshow(np.abs(I_lena - np.float64(IG)/256)) # add image
plt.gray()
plt.title('roznica') # add title
plt.axis('off') # disable display of the coordinate system
plt.show() # display

# %% [markdown]
# #### Zadanie 1.6

# %%
IGE = cv2.equalizeHist(IG)
plt.figure(1) # create figure
plt.imshow(IGE) # add image
plt.gray()
plt.title('wyrownanie') # add title
plt.axis('off') # disable display of the coordinate system
plt.show() # display

# %%
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
I_CLAHE = clahe.apply(IG)

plt.figure(1) # create figure
plt.imshow(I_CLAHE) # add image
plt.gray()
plt.title('wyrownanie') # add title
plt.axis('off') # disable display of the coordinate system
plt.show() # display
